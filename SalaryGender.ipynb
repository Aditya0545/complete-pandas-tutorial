# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pwd
# Out:
# /home/aditya/Downloads/MACHINE-LEARNING/Case-Study-1

# %%
# !ls
# Out:
# dataset  SalaryGender.ipynb

# %%
df = pd.read_csv('dataset/SalaryGender.csv')
# another option is --> read_csv(r"d:\salarygender.csv")

# %%
df
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
df.describe()
# Out:
#            Salary      Gender         Age         PhD
# count  100.000000  100.000000  100.000000  100.000000
# mean    52.524500    0.500000   46.880000    0.390000
# std     42.220933    0.502519   15.271469    0.490207
# min      0.250000    0.000000   20.000000    0.000000
# 25%     20.000000    0.000000   31.500000    0.000000
# 50%     39.300000    0.500000   49.000000    0.000000
# 75%     75.500000    1.000000   60.000000    1.000000
# max    190.000000    1.000000   77.000000    1.000000

# %%
df.head()
# Out:
#    Salary  Gender  Age  PhD
# 0   140.0       1   47    1
# 1    30.0       0   65    1
# 2    35.1       0   56    0
# 3    30.0       1   23    0
# 4    80.0       0   53    1

# %%
df.corr()
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.259312  0.477043  0.555560
# Gender  0.259312  1.000000  0.160580  0.184521
# Age     0.477043  0.160580  1.000000  0.353081
# PhD     0.555560  0.184521  0.353081  1.000000

# %%
sns.heatmap(df.corr(), cmap = 'coolwarm', annot = True)
# Out:
# <Axes: >

# %%
sns.scatterplot(data = df, x = "Salary", y = "Age", hue = "Gender")
# Out:
# <Axes: xlabel='Salary', ylabel='Age'>

# %%
df.corr()
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.259312  0.477043  0.555560
# Gender  0.259312  1.000000  0.160580  0.184521
# Age     0.477043  0.160580  1.000000  0.353081
# PhD     0.555560  0.184521  0.353081  1.000000

# %%
df.corr(method = "kendall")
# Out:
#           Salary    Gender       Age       PhD
# Salary  1.000000  0.145310  0.334499  0.477900
# Gender  0.145310  1.000000  0.159001  0.184521
# Age     0.334499  0.159001  1.000000  0.276267
# PhD     0.477900  0.184521  0.276267  1.000000

# %%
df
# Out:
#     Salary  Gender  Age  PhD
# 0    140.0       1   47    1
# 1     30.0       0   65    1
# 2     35.1       0   56    0
# 3     30.0       1   23    0
# 4     80.0       0   53    1
# ..     ...     ...  ...  ...
# 95    18.6       1   26    0
# 96   152.0       1   56    1
# 97     1.8       1   28    0
# 98    35.0       0   44    0
# 99     4.0       0   24    0
#
# [100 rows x 4 columns]

# %%
sns.scatterplot(data = df, x = "Age", y = "Salary")
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
sns.relplot(data = df, x = "Age", y = "Salary", hue = "Gender", col = "PhD")

# %%
# df['Gender'] = df['Gender'].map({0: "Female", 1: "Male"})

# %%
plt.plot(df["Age"], df["Salary"])
plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("Salary Over Age")
# Out:
# Text(0.5, 1.0, 'Salary Over Age')
